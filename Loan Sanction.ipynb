# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from pandas import DataFrame, Series

# %%
d=pd.read_excel("loan_sanction.xlsx")

# %%
pwd
# Out:
# 'C:\\Users\\nitin'

# %%
d
# Out:
#      Unnamed: 0.1  Unnamed: 0   Loan_ID Gender Married Dependents  \
# 0               0           0  LP001015   Male     Yes          0
# 1               1           1  LP001022   Male     Yes          1
# 2               2           2  LP001031   Male     Yes          2
# 3               3           3  LP001035   Male     Yes          2
# 4               4           4  LP001051   Male      No          0
# ..            ...         ...       ...    ...     ...        ...
# 362           362         362  LP002971   Male     Yes         3+
# 363           363         363  LP002975   Male     Yes          0
# 364           364         364  LP002980   Male      No          0
# 365           365         365  LP002986   Male     Yes          0
# 366           366         366  LP002989   Male      No          0
#
#         Education Self_Employed  ApplicantIncome  CoapplicantIncome  \
# 0        Graduate            No             5720                  0
# ...

# %%
d.describe()
# Out:
#        Unnamed: 0  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# count  367.000000       367.000000         367.000000  367.000000
# mean   183.000000      4805.599455        1569.577657  135.980926
# std    106.088014      4910.685399        2334.232099   60.959739
# min      0.000000         0.000000           0.000000   28.000000
# 25%     91.500000      2864.000000           0.000000  101.000000
# 50%    183.000000      3786.000000        1025.000000  125.000000
# 75%    274.500000      5060.000000        2430.500000  157.500000
# max    366.000000     72529.000000       24000.000000  550.000000
#
#        Loan_Amount_Term  Credit_History
# count        367.000000           367.0
# mean         342.822888             1.0
# std           64.658402             0.0
# min            6.000000             1.0
# 25%          360.000000             1.0
# 50%          360.000000             1.0
# 75%          360.000000             1.0
# max          480.000000             1.0

# %%
d.shape
# Out:
# (367, 13)

# %%
d.dtypes
# Out:
# Unnamed: 0            int64
# Loan_ID              object
# Gender               object
# Married              object
# Dependents           object
# Education            object
# Self_Employed        object
# ApplicantIncome       int64
# CoapplicantIncome     int64
# LoanAmount            int64
# Loan_Amount_Term      int64
# Credit_History        int64
# Property_Area        object
# dtype: object

# %%
d.describe(include="object")
# Out:
#          Loan_ID Gender Married Dependents Education Self_Employed  \
# count        367    367     367        357       367           367
# unique       367      2       2          4         2             2
# top     LP001015   Male     Yes          0  Graduate            No
# freq           1    297     233        200       283           330
#
#        Property_Area
# count            367
# unique             3
# top            Urban
# freq             140

# %%
for col in d.describe(include="object").columns:
    print (col)
    print (d[col].unique())
    print ("-"*50)
# Out:
# Loan_ID
# ['LP001015' 'LP001022' 'LP001031' 'LP001035' 'LP001051' 'LP001054'
#  'LP001055' 'LP001056' 'LP001059' 'LP001067' 'LP001078' 'LP001082'
#  'LP001083' 'LP001094' 'LP001096' 'LP001099' 'LP001105' 'LP001107'
#  'LP001108' 'LP001115' 'LP001121' 'LP001124' 'LP001128' 'LP001135'
#  'LP001149' 'LP001153' 'LP001163' 'LP001169' 'LP001174' 'LP001176'
#  'LP001177' 'LP001183' 'LP001185' 'LP001187' 'LP001190' 'LP001203'
#  'LP001208' 'LP001210' 'LP001211' 'LP001219' 'LP001220' 'LP001221'
#  'LP001226' 'LP001230' 'LP001231' 'LP001232' 'LP001237' 'LP001242'
#  'LP001268' 'LP001270' 'LP001284' 'LP001287' 'LP001291' 'LP001298'
#  'LP001312' 'LP001313' 'LP001317' 'LP001321' 'LP001323' 'LP001324'
#  'LP001332' 'LP001335' 'LP001338' 'LP001347' 'LP001348' 'LP001351'
#  'LP001352' 'LP001358' 'LP001359' 'LP001361' 'LP001366' 'LP001368'
#  'LP001375' 'LP001380' 'LP001386' 'LP001400' 'LP001407' 'LP001413'
#  'LP001415' 'LP001419' 'LP001420' 'LP001428' 'LP001445' 'LP001446'
# ...

# %%
d.cov()
# Out:
# C:\Users\nitin\AppData\Local\Temp\ipykernel_46504\491627619.py:1: FutureWarning: The default value of numeric_only in DataFrame.cov is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   d.cov()
#                      Unnamed: 0  ApplicantIncome  CoapplicantIncome  \
# Unnamed: 0         11254.666667    -7.629126e+02      -1.006178e+03
# ApplicantIncome     -762.912568     2.411483e+07      -1.264732e+06
# CoapplicantIncome  -1006.177596    -1.264732e+06       5.448639e+06
# LoanAmount          -490.519126     1.463053e+05       2.134902e+04
# Loan_Amount_Term      53.661202     7.404336e+03      -1.302941e+03
# Credit_History         0.000000     0.000000e+00       0.000000e+00
#
#                       LoanAmount  Loan_Amount_Term  Credit_History
# Unnamed: 0           -490.519126         53.661202             0.0
# ApplicantIncome    146305.306547       7404.335969             0.0
# ...

# %%
d.corr()
# Out:
# C:\Users\nitin\AppData\Local\Temp\ipykernel_46504\2319908662.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   d.corr()
#                    Unnamed: 0  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# Unnamed: 0           1.000000        -0.001464          -0.004063   -0.075848
# ApplicantIncome     -0.001464         1.000000          -0.110335    0.488737
# CoapplicantIncome   -0.004063        -0.110335           1.000000    0.150034
# LoanAmount          -0.075848         0.488737           0.150034    1.000000
# Loan_Amount_Term     0.007823         0.023319          -0.008633    0.091867
# Credit_History            NaN              NaN                NaN         NaN
#
#                    Loan_Amount_Term  Credit_History
# Unnamed: 0                 0.007823             NaN
# ...

# %%
d.duplicated().sum()
# Out:
# 0

# %% [markdown]
# no duplicate row and nothing to drop

# %%
d.isnull().sum()
# Out:
# Unnamed: 0            0
# Loan_ID               0
# Gender                0
# Married               0
# Dependents           10
# Education             0
# Self_Employed         0
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            0
# Loan_Amount_Term      0
# Credit_History        0
# Property_Area         0
# dtype: int64

# %%
d.dropna(axis=0)
# Out:
#      Unnamed: 0   Loan_ID Gender Married Dependents     Education  \
# 0             0  LP001015   Male     Yes          0      Graduate
# 1             1  LP001022   Male     Yes          1      Graduate
# 2             2  LP001031   Male     Yes          2      Graduate
# 3             3  LP001035   Male     Yes          2      Graduate
# 4             4  LP001051   Male      No          0  Not Graduate
# ..          ...       ...    ...     ...        ...           ...
# 362         362  LP002971   Male     Yes         3+  Not Graduate
# 363         363  LP002975   Male     Yes          0      Graduate
# 364         364  LP002980   Male      No          0      Graduate
# 365         365  LP002986   Male     Yes          0      Graduate
# 366         366  LP002989   Male      No          0      Graduate
#
#     Self_Employed  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# 0              No             5720                  0         110
# ...

# %% [markdown]
# delete the row

# %%
d['Gender'].mode()
# Out:
# 0    Male
# Name: Gender, dtype: object

# %%
d['Gender'].isnull().sum()
# Out:
# 0

# %%
d['Self_Employed'].isnull().sum()
# Out:
# 0

# %%
d.columns
# Out:
# Index(['Unnamed: 0', 'Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area'],
#       dtype='object')

# %%
d['LoanAmount'].isnull().sum()
# Out:
# 0

# %%
d.head(5)
# Out:
#    Unnamed: 0   Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0           0  LP001015   Male     Yes          0      Graduate            No
# 1           1  LP001022   Male     Yes          1      Graduate            No
# 2           2  LP001031   Male     Yes          2      Graduate            No
# 3           3  LP001035   Male     Yes          2      Graduate            No
# 4           4  LP001051   Male      No          0  Not Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5720                  0         110               360
# 1             3076               1500         126               360
# 2             5000               1800         208               360
# 3             2340               2546         100               360
# 4             3276                  0          78               360
#
#    Credit_History Property_Area
# 0               1         Urban
# ...

# %%
n=d.to_excel("loan_sanction.xlsx")

# %%
d.shape
# Out:
# (367, 13)

# %%
d.columns
# Out:
# Index(['Unnamed: 0', 'Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area'],
#       dtype='object')

# %%
d.describe()
# Out:
#        Unnamed: 0  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# count  367.000000       367.000000         367.000000  367.000000
# mean   183.000000      4805.599455        1569.577657  135.980926
# std    106.088014      4910.685399        2334.232099   60.959739
# min      0.000000         0.000000           0.000000   28.000000
# 25%     91.500000      2864.000000           0.000000  101.000000
# 50%    183.000000      3786.000000        1025.000000  125.000000
# 75%    274.500000      5060.000000        2430.500000  157.500000
# max    366.000000     72529.000000       24000.000000  550.000000
#
#        Loan_Amount_Term  Credit_History
# count        367.000000           367.0
# mean         342.822888             1.0
# std           64.658402             0.0
# min            6.000000             1.0
# 25%          360.000000             1.0
# 50%          360.000000             1.0
# 75%          360.000000             1.0
# max          480.000000             1.0

# %%
d.select_dtypes(include=[np.number])
# Out:
#      Unnamed: 0  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# 0             0             5720                  0         110
# 1             1             3076               1500         126
# 2             2             5000               1800         208
# 3             3             2340               2546         100
# 4             4             3276                  0          78
# ..          ...              ...                ...         ...
# 362         362             4009               1777         113
# 363         363             4158                709         115
# 364         364             3250               1993         126
# 365         365             5000               2393         158
# 366         366             9200                  0          98
#
#      Loan_Amount_Term  Credit_History
# 0                 360               1
# 1                 360               1
# 2                 360               1
# 3                 360               1
# ...

# %%
n=d.select_dtypes(exclude=['object'])
n
# Out:
#      Unnamed: 0  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# 0             0             5720                  0         110
# 1             1             3076               1500         126
# 2             2             5000               1800         208
# 3             3             2340               2546         100
# 4             4             3276                  0          78
# ..          ...              ...                ...         ...
# 362         362             4009               1777         113
# 363         363             4158                709         115
# 364         364             3250               1993         126
# 365         365             5000               2393         158
# 366         366             9200                  0          98
#
#      Loan_Amount_Term  Credit_History
# 0                 360               1
# 1                 360               1
# 2                 360               1
# 3                 360               1
# ...

# %%
d[d['Self_Employed'] == 'Yes']
# Out:
#      Unnamed: 0.1  Unnamed: 0   Loan_ID  Gender Married Dependents  \
# 5               5           5  LP001054    Male     Yes          0
# 37             37          37  LP001210    Male     Yes          0
# 38             38          38  LP001211    Male      No          0
# 49             49          49  LP001270    Male     Yes         3+
# 54             54          54  LP001312    Male     Yes          0
# 61             61          61  LP001335    Male     Yes          0
# 73             73          73  LP001380    Male     Yes          0
# 77             77          77  LP001413    Male      No          0
# 90             90          90  LP001475    Male     Yes          0
# 110           110         110  LP001584  Female      No          0
# 132           132         132  LP001728    Male     Yes          1
# 143           143         143  LP001791    Male     Yes          0
# 144           144         144  LP001794    Male     Yes          2
# ...

# %%
d[d["Property_Area"]=='Urban']
# Out:
#      Unnamed: 0   Loan_ID  Gender Married Dependents     Education  \
# 0             0  LP001015    Male     Yes          0      Graduate
# 1             1  LP001022    Male     Yes          1      Graduate
# 2             2  LP001031    Male     Yes          2      Graduate
# 3             3  LP001035    Male     Yes          2      Graduate
# 4             4  LP001051    Male      No          0  Not Graduate
# ..          ...       ...     ...     ...        ...           ...
# 356         356  LP002935    Male     Yes          1      Graduate
# 357         357  LP002952    Male      No          0      Graduate
# 360         360  LP002965  Female     Yes          0      Graduate
# 362         362  LP002971    Male     Yes         3+  Not Graduate
# 363         363  LP002975    Male     Yes          0      Graduate
#
#     Self_Employed  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# 0              No             5720                  0         110
# ...

# %%
d['Gender'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
d.to_excel("jvs.xlsx",index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 d.to_excel("jvs.xlsx",index=False)
#
# NameError: name 'd' is not defined

# %%
d['Gender'].value_counts()
# Out:
# Male      297
# Female     70
# Name: Gender, dtype: int64
